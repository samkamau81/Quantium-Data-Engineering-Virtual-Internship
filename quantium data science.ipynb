# %% [markdown]
# ## Quantium Task1
# #### By Samuel Waweru, Mechatronic Engineering Undergraduate 2025.
#
# Analysis of Customer Data and data visualization.
# Quantium’s retail analytics team :Chips and their purchasing behaviour within the region.

# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("S:\code\Quantium_proj\QVI_purchase_behaviour.csv")
# to output the first 30 items
df.head(30)
# Out:
#     LYLTY_CARD_NBR               LIFESTAGE PREMIUM_CUSTOMER
# 0             1000   YOUNG SINGLES/COUPLES          Premium
# 1             1002   YOUNG SINGLES/COUPLES       Mainstream
# 2             1003          YOUNG FAMILIES           Budget
# 3             1004   OLDER SINGLES/COUPLES       Mainstream
# 4             1005  MIDAGE SINGLES/COUPLES       Mainstream
# 5             1007   YOUNG SINGLES/COUPLES           Budget
# 6             1009            NEW FAMILIES          Premium
# 7             1010   YOUNG SINGLES/COUPLES       Mainstream
# 8             1011   OLDER SINGLES/COUPLES       Mainstream
# 9             1012          OLDER FAMILIES       Mainstream
# 10            1013                RETIREES           Budget
# 11            1016          OLDER FAMILIES       Mainstream
# 12            1018   YOUNG SINGLES/COUPLES       Mainstream
# 13            1019   OLDER SINGLES/COUPLES          Premium
# 14            1020   YOUNG SINGLES/COUPLES       Mainstream
# ...

# %%
df1=pd.read_csv("QVI_transaction_data.csv")
# to output the first 30 items
df1.head(30)
# Out:
#      DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 0   43390          1            1000       1         5
# 1   43599          1            1307     348        66
# 2   43605          1            1343     383        61
# 3   43329          2            2373     974        69
# 4   43330          2            2426    1038       108
# 5   43604          4            4074    2982        57
# 6   43601          4            4149    3333        16
# 7   43601          4            4196    3539        24
# 8   43332          5            5026    4525        42
# 9   43330          7            7150    6900        52
# 10  43602          7            7215    7176        16
# 11  43332          8            8294    8221       114
# 12  43603          9            9208    8634        15
# 13  43329         13           13213   12447        92
# 14  43600         19           19272   16686        44
# 15  43604         20           20164   17136        54
# ...

# %% [markdown]
# ### Data Cleaning
# Examine transaction data – look for inconsistencies, missing data across the data set, outliers, correctly identified category items,numeric data across all tables. If you determine any anomalies make the necessary changes in the dataset and save it.Having clean data will help when it comes to your analysis.

# %%
#Data Frame df
df1.dropna(inplace = True)
df1.head(30)
# Out:
#      DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 0   43390          1            1000       1         5
# 1   43599          1            1307     348        66
# 2   43605          1            1343     383        61
# 3   43329          2            2373     974        69
# 4   43330          2            2426    1038       108
# 5   43604          4            4074    2982        57
# 6   43601          4            4149    3333        16
# 7   43601          4            4196    3539        24
# 8   43332          5            5026    4525        42
# 9   43330          7            7150    6900        52
# 10  43602          7            7215    7176        16
# 11  43332          8            8294    8221       114
# 12  43603          9            9208    8634        15
# 13  43329         13           13213   12447        92
# 14  43600         19           19272   16686        44
# 15  43604         20           20164   17136        54
# ...

# %% [markdown]
# Examine customer data – check for similar issues in the customer data, look for nulls and when you are happy merge the transaction and customer data together so it’s ready for the analysis ensuring you save your files along the way.

# %%
#Data Frame df
df.dropna(inplace = True)
df.head(30)
# Out:
#     LYLTY_CARD_NBR               LIFESTAGE PREMIUM_CUSTOMER
# 0             1000   YOUNG SINGLES/COUPLES          Premium
# 1             1002   YOUNG SINGLES/COUPLES       Mainstream
# 2             1003          YOUNG FAMILIES           Budget
# 3             1004   OLDER SINGLES/COUPLES       Mainstream
# 4             1005  MIDAGE SINGLES/COUPLES       Mainstream
# 5             1007   YOUNG SINGLES/COUPLES           Budget
# 6             1009            NEW FAMILIES          Premium
# 7             1010   YOUNG SINGLES/COUPLES       Mainstream
# 8             1011   OLDER SINGLES/COUPLES       Mainstream
# 9             1012          OLDER FAMILIES       Mainstream
# 10            1013                RETIREES           Budget
# 11            1016          OLDER FAMILIES       Mainstream
# 12            1018   YOUNG SINGLES/COUPLES       Mainstream
# 13            1019   OLDER SINGLES/COUPLES          Premium
# 14            1020   YOUNG SINGLES/COUPLES       Mainstream
# ...

# %%
# merging the two DataFrame
frames = [df, df1]
result = pd.concat(frames)
result
# Out:
#         LYLTY_CARD_NBR               LIFESTAGE PREMIUM_CUSTOMER     DATE  \
# 0                 1000   YOUNG SINGLES/COUPLES          Premium      NaN
# 1                 1002   YOUNG SINGLES/COUPLES       Mainstream      NaN
# 2                 1003          YOUNG FAMILIES           Budget      NaN
# 3                 1004   OLDER SINGLES/COUPLES       Mainstream      NaN
# 4                 1005  MIDAGE SINGLES/COUPLES       Mainstream      NaN
# ...                ...                     ...              ...      ...
# 264831          272319                     NaN              NaN  43533.0
# 264832          272358                     NaN              NaN  43325.0
# 264833          272379                     NaN              NaN  43410.0
# 264834          272379                     NaN              NaN  43461.0
# 264835          272380                     NaN              NaN  43365.0
#
#         STORE_NBR    TXN_ID  PROD_NBR  \
# 0             NaN       NaN       NaN
# ...

# %% [markdown]
# Data analysis and customer segments – in your analysis make sure you define the metrics – look at total sales, drivers of sales, where the highest sales are coming from etc. Explore the data, create charts and graphs as well as noting any interesting trends and/or insights you find. These will all form part of our report to Julia.

# %%
#Graphs

#Graph 1: Product Quality vs Total Sales

x = result.TOT_SALES
y = result.PROD_QTY

fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(x, y, color='lightblue', linewidth=3)

ax.scatter([2,4,6],[5,15,25],color='darkgreen',marker='^')

ax.set_xlim(1, 6.5)
ax.set_xlabel('Total Sales')
ax.set_ylabel('Product Quality')
ax.set_title('Product Quality Vs Total Sales')
plt.savefig('Graph.png')

plt.show()

# %%
# Graph 2:The number of clients according to choices
print(result.groupby(['PREMIUM_CUSTOMER'])['PREMIUM_CUSTOMER'].count())
Premium =result['PREMIUM_CUSTOMER'].str.contains('Premium').value_counts()[True] #18922
Mainstream = result['PREMIUM_CUSTOMER'].str.contains('Mainstream').value_counts()[True] #29245
Budget = result['PREMIUM_CUSTOMER'].str.contains('Budget').value_counts()[True] #18922

labels = ['Premium', 'Mainstream', 'Budget']
sizes = [Premium, Mainstream, Budget]
colors = ['yellowgreen', 'gold', 'lightskyblue']
patches, texts = plt.pie(sizes, colors=colors, shadow=True, startangle=90)
plt.legend(patches, labels, loc="best")
plt.axis('equal')
plt.tight_layout()
plt.show()
# Out:
# PREMIUM_CUSTOMER
# Budget        24470
# Mainstream    29245
# Premium       18922
# Name: PREMIUM_CUSTOMER, dtype: int64

# %%
# Graph 3:Lifestage Group count graphs
print(result.groupby(['LIFESTAGE'])['LIFESTAGE'].count())
NEW_FAMILIES =result['LIFESTAGE'].str.contains('NEW FAMILIES').value_counts()[True] 
YOUNG_SINGLES_COUPLES = result['LIFESTAGE'].str.contains('YOUNG SINGLES/COUPLES').value_counts()[True] 
RETIREES = result['LIFESTAGE'].str.contains('RETIREES').value_counts()[True]
OLDER_SINGLES_COUPLES = result['LIFESTAGE'].str.contains('OLDER SINGLES/COUPLES').value_counts()[True] 
MIDAGE_SINGLES_COUPLES = result['LIFESTAGE'].str.contains('MIDAGE SINGLES/COUPLES').value_counts()[True] 

labels = ['NEW FAMILIES', 'YOUNG SINGLES/COUPLES', 'RETIREES','OLDER SINGLES/COUPLES','MIDAGE SINGLES/COUPLES']
sizes = [NEW_FAMILIES,YOUNG_SINGLES_COUPLES, RETIREES,OLDER_SINGLES_COUPLES, MIDAGE_SINGLES_COUPLES]
colors = ['yellowgreen', 'gold', 'lightskyblue','green','purple']
patches, texts = plt.pie(sizes, colors=colors, shadow=True, startangle=90)
plt.legend(patches, labels, loc="best")
plt.axis('equal')
plt.tight_layout()
plt.show()
# Out:
# LIFESTAGE
# MIDAGE SINGLES/COUPLES     7275
# NEW FAMILIES               2549
# OLDER FAMILIES             9780
# OLDER SINGLES/COUPLES     14609
# RETIREES                  14805
# YOUNG FAMILIES             9178
# YOUNG SINGLES/COUPLES     14441
# Name: LIFESTAGE, dtype: int64

# %% [markdown]
# ### Conclusion
# To sum up ,I've been able to deduce that;
# - From Graph 1, the total sales are dependent on the product quality i.e. high quality leads to high sales.
# - Most customers are not after quality (premium) but neither are they after quantity (Budget), they are mainstream followed closely by budget and lastly premium.(Graph 2)
# - Most of the clientele are among the retirees and this might be as a result of a lot of time on their hands since they are not working.(Graph 3)
